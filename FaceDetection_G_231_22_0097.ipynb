# %% [markdown]
# <a href="https://colab.research.google.com/github/kholiqhidayat/UAS-Praktikum-Pengolahan-Citra-PCD/blob/main/FaceDetection_G_231_22_0097.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
img = cv2.imread("/content/drive/MyDrive/Temanbisnis.jpg")
assert img is not None, "Temanbisnis.jpg tidak ditemukan."

gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")
faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30,30))

for (x,y,w,h) in faces:
  cv2.rectangle(img, (x,y), (x+w, y+h), (0,255,0),2)

plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB)); plt.axis('off'); plt.title(f'Faces detected: {len(faces)}');plt.show()

# %%
# !pip install mtcnn
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 26.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 43.9 MB/s eta 0:00:00
# ...

# %%
from mtcnn import MTCNN
import cv2

img = cv2.imread("/content/drive/MyDrive/Temanbisnis.jpg")
rgb_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

detector = MTCNN()
faces = detector.detect_faces(rgb_img)

for face in faces:
    x, y, w, h = face['box']
    cv2.rectangle(img, (x,y), (x+w, y+h), (0,255,0),2)

plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB)); plt.axis('off'); plt.title(f'Faces Detected: {len(faces)}');plt.show
cv2.waitKey(0)
cv2.destroyAllWindows()
